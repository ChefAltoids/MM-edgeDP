# %% [markdown]
# # Query Norm Rescue Ablation (Colab)
#
# This notebook runs the tested ablation script for `none`, `l2_row`, `clip_l2`, and `soft_l2`.

# %%
import os, subprocess, sys
repo_url = os.environ.get('MMEDGEDP_REPO_URL', '').strip()
if not repo_url:
    raise RuntimeError('Set MMEDGEDP_REPO_URL to your GitHub repo URL first.')
subprocess.check_call(['git', 'clone', repo_url, '/content/MM-edgeDP'])
# %cd /content/MM-edgeDP
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', '-r', 'requirements-colab.txt'])

# %%
# %cd /content/MM-edgeDP
# !python notebooks/query_norm_rescue_ablation_colab.py
